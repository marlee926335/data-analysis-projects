# %% [markdown]
# # Exercises: Creating, Updating, and Destroying Objects
#
# For the exercises, you will be working with objects and data you create. Before opening this notebook, make sure that you have set up the new connection to the server and that you have located the database and your schema.
#
# ## Object Creation
#
# Before coding, think of three things you want to make. These could be coding projects, new recipes, or planned projects for a woodworking hobby. Brainstorm the appropriate column names and data types as well.
#
# Create a table under your schema called `planned_makes`.

# %%
CREATE TABLE Sept2025JunkDB.marcus_lee.planned_makes (
    ProjectID INT IDENTITY(1,1) PRIMARY KEY,
    ProjectName VARCHAR(200),
    StartDate DATE
    EstimatedEndDate DATE

)

# %% [markdown]
# Add three rows to your table that are your planned makes.

# %%
INSERT INTO Sep2025JunkDB.marcus_lee.planned_makes
VALUES ('Date Night app', '10-20-2026', '10-20-2027')

INSERT INTO Sep2025JunkDB.marcus_lee.planned_makes
VALUES ('Bathroom Remodel', '1-2-2026', '6-20-2026')

INSERT INTO Sep2025JunkDB.marcus_lee.planned_makes
VALUES ('Gym Remodel', '2-13-2026', '3-13-2026')

# %% [markdown]
# ## Update a Row
#
# Change different values in one of your three rows.

# %%
UPDATE Sep2025JunkDB.marcus_lee.planned_makes
set StartDate = '06-01-2026'
WHERE ProjectID = 3

UPDATE Sep2025JunkDB.marcus_lee.planned_makes
set EstimatedEndDate = '12-01-2026'
WHERE ProjectID = 3

# %% [markdown]
# ## Delete a Row
#
# Delete one of the rows from your table.

# %%
DELETE from Sep2025JunkDB.marcus_lee.planned_makes
WHERE ProjectID = 2

# %% [markdown]
# ## Drop the Table
#
# While this has been fun, it is time to drop the table!

# %%
DROP TABLE Sep2025JunkDB.marcus_lee.planned_makes
